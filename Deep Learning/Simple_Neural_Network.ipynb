# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdas2001/ML-Workbook/blob/main/Simple_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers.core import Dense
import numpy as np

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

model = Sequential()
model.add(Dense(4, input_dim=2, activation='sigmoid'))
model.add(Dense(1, input_dim=4, activation='sigmoid'))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
model.fit(X, y, epochs=30000, verbose=2)

print("Predictions after the training ...")
print(model.predict(X))
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 - 0s - loss: 4.3270e-07 - binary_accuracy: 1.0000
# Epoch 27504/30000
# 1/1 - 0s - loss: 4.3253e-07 - binary_accuracy: 1.0000
# Epoch 27505/30000
# 1/1 - 0s - loss: 4.3237e-07 - binary_accuracy: 1.0000
# Epoch 27506/30000
# 1/1 - 0s - loss: 4.3223e-07 - binary_accuracy: 1.0000
# Epoch 27507/30000
# 1/1 - 0s - loss: 4.3204e-07 - binary_accuracy: 1.0000
# Epoch 27508/30000
# 1/1 - 0s - loss: 4.3191e-07 - binary_accuracy: 1.0000
# Epoch 27509/30000
# 1/1 - 0s - loss: 4.3169e-07 - binary_accuracy: 1.0000
# Epoch 27510/30000
# 1/1 - 0s - loss: 4.3157e-07 - binary_accuracy: 1.0000
# Epoch 27511/30000
# 1/1 - 0s - loss: 4.3137e-07 - binary_accuracy: 1.0000
# Epoch 27512/30000
# 1/1 - 0s - loss: 4.3125e-07 - binary_accuracy: 1.0000
# Epoch 27513/30000
# 1/1 - 0s - loss: 4.3103e-07 - binary_accuracy: 1.0000
# Epoch 27514/30000
# 1/1 - 0s - loss: 4.3089e-07 - binary_accuracy: 1.0000
# Epoch 27515/30000
# ...
